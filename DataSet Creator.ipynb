# %%
import pandas as pd
import os
import shutil

# %%
#Create the data for positive samples
FILE_PATH = "chestxray/metadata.csv"
IMAGE_PATH = "chestxray/images"

# %%
df = pd.read_csv(FILE_PATH)
print(df.shape)
# Out:
# (561, 28)

# %%
df.head
# Out:
# <bound method NDFrame.head of      patientid offset sex   age     finding survival intubated  \
# 0            2      0   M  65.0    COVID-19        Y       NaN
# 1            2      3   M  65.0    COVID-19        Y       NaN
# 2            2      5   M  65.0    COVID-19        Y       NaN
# 3            2      6   M  65.0    COVID-19        Y       NaN
# 4            4      0   F  52.0    COVID-19      NaN       NaN
# ..         ...    ...  ..   ...         ...      ...       ...
# 556        285      ?   F  64.0        todo        ?         ?
# 557        286      ?   F  56.0        todo        ?         ?
# 558        286      ?   F  56.0        todo        ?         ?
# 559        287      7   M  80.0  Legionella        N       NaN
# 560        287      7   M  80.0  Legionella        N       NaN
#
#     intubation_present went_icu in_icu  ... modality              date  \
# 0                  NaN      NaN    NaN  ...    X-ray  January 22, 2020
# 1                  NaN      NaN    NaN  ...    X-ray  January 25, 2020
# 2                  NaN      NaN    NaN  ...    X-ray  January 27, 2020
# 3                  NaN      NaN    NaN  ...    X-ray  January 28, 2020
# 4                  NaN      NaN    NaN  ...    X-ray  January 25, 2020
# ..                 ...      ...    ...  ...      ...               ...
# 556                  ?        ?      ?  ...    X-ray                 ?
# 557                  ?        ?      ?  ...    X-ray                 ?
# 558                  ?        ?      ?  ...    X-ray                 ?
# 559                NaN        Y    NaN  ...    X-ray              2013
# 560                NaN        Y    NaN  ...    X-ray              2013
#
#                                               location  folder  \
# 0          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4    Changhua Christian Hospital, Changhua City, Ta...  images
# ..                                                 ...     ...
# 556                                                  ?  images
# 557                                                  ?  images
# 558                                                  ?  images
# 559                                        Rome, Italy  images
# 560                                        Rome, Italy  images
#
#                                               filename                   doi  \
# 0    auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1    auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2    auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3    auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                                nejmc2001573_f1a.jpeg  10.1056/NEJMc2001573
# ..                                                 ...                   ...
# 556                                      000007-15.jpg                   NaN
# 557                                      000002-27.jpg                   NaN
# 558                                      000003-24.jpg                   NaN
# 559                                      000001-27.jpg                   NaN
# 560                                      000002-29.jpg                   NaN
#
#                                                    url          license  \
# 0    https://www.nejm.org/doi/full/10.1056/NEJMc200...              NaN
# 1    https://www.nejm.org/doi/full/10.1056/NEJMc200...              NaN
# 2    https://www.nejm.org/doi/full/10.1056/NEJMc200...              NaN
# 3    https://www.nejm.org/doi/full/10.1056/NEJMc200...              NaN
# 4    https://www.nejm.org/doi/full/10.1056/NEJMc200...              NaN
# ..                                                 ...              ...
# 556                 https://www.eurorad.org/case/10483  CC BY-NC-SA 4.0
# 557                 https://www.eurorad.org/case/10515  CC BY-NC-SA 4.0
# 558                 https://www.eurorad.org/case/10515  CC BY-NC-SA 4.0
# 559                 https://www.eurorad.org/case/10665  CC BY-NC-SA 4.0
# 560                 https://www.eurorad.org/case/10665  CC BY-NC-SA 4.0
#
#                                         clinical_notes other_notes
# 0    On January 22, 2020, a 65-year-old man with a ...         NaN
# 1    On January 22, 2020, a 65-year-old man with a ...         NaN
# 2    On January 22, 2020, a 65-year-old man with a ...         NaN
# 3    On January 22, 2020, a 65-year-old man with a ...         NaN
# 4     diffuse infiltrates in the bilateral lower lungs         NaN
# ..                                                 ...         ...
# 556  Patient with one month history of fever, cough...         NaN
# 557  A 56-year-old lady with advanced multiple scle...         NaN
# 558  A 56-year-old lady with advanced multiple scle...         NaN
# 559  The patient presented to the emergency room af...         NaN
# 560  The patient presented to the emergency room af...         NaN
#
# [561 rows x 28 columns]>

# %%
TARGET_DIR = "Dataset/Covid"
if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print('Covid folder created')
# Out:
# Covid folder created

# %%
cnt = 0

for (i,row) in df.iterrows():
    if row["finding"] == "COVID-19" and row["view"]=="PA":
        filename = row["filename"]
        image_path = os.path.join(IMAGE_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("Moving image",cnt)
        cnt+=1
        
#print(cnt)
# Out:
# Moving image 0
# Moving image 1
# Moving image 2
# Moving image 3
# Moving image 4
# Moving image 5
# Moving image 6
# Moving image 7
# Moving image 8
# Moving image 9
# Moving image 10
# Moving image 11
# Moving image 12
# Moving image 13
# Moving image 14
# Moving image 15
# Moving image 16
# Moving image 17
# Moving image 18
# Moving image 19
# Moving image 20
# Moving image 21
# Moving image 22
# Moving image 23
# Moving image 24
# Moving image 25
# Moving image 26
# Moving image 27
# Moving image 28
# Moving image 29
# Moving image 30
# Moving image 31
# Moving image 32
# Moving image 33
# Moving image 34
# Moving image 35
# Moving image 36
# Moving image 37
# Moving image 38
# Moving image 39
# Moving image 40
# Moving image 41
# Moving image 42
# Moving image 43
# Moving image 44
# Moving image 45
# Moving image 46
# Moving image 47
# Moving image 48
# Moving image 49
# Moving image 50
# Moving image 51
# Moving image 52
# Moving image 53
# Moving image 54
# Moving image 55
# Moving image 56
# Moving image 57
# Moving image 58
# Moving image 59
# Moving image 60
# Moving image 61
# Moving image 62
# Moving image 63
# Moving image 64
# Moving image 65
# Moving image 66
# Moving image 67
# Moving image 68
# Moving image 69
# Moving image 70
# Moving image 71
# Moving image 72
# Moving image 73
# Moving image 74
# Moving image 75
# Moving image 76
# Moving image 77
# Moving image 78
# Moving image 79
# Moving image 80
# Moving image 81
# Moving image 82
# Moving image 83
# Moving image 84
# Moving image 85
# Moving image 86
# Moving image 87
# Moving image 88
# Moving image 89
# Moving image 90
# Moving image 91
# Moving image 92
# Moving image 93
# Moving image 94
# Moving image 95
# Moving image 96
# Moving image 97
# Moving image 98
# Moving image 99
# Moving image 100
# Moving image 101
# Moving image 102
# Moving image 103
# Moving image 104
# Moving image 105
# Moving image 106
# Moving image 107
# Moving image 108
# Moving image 109
# Moving image 110
# Moving image 111
# Moving image 112
# Moving image 113
# Moving image 114
# Moving image 115
# Moving image 116
# Moving image 117
# Moving image 118
# Moving image 119
# Moving image 120
# Moving image 121
# Moving image 122
# Moving image 123
# Moving image 124
# Moving image 125
# Moving image 126
# Moving image 127
# Moving image 128
# Moving image 129
# Moving image 130
# Moving image 131
# Moving image 132
# Moving image 133
# Moving image 134
# Moving image 135
# Moving image 136
# Moving image 137
# Moving image 138
# Moving image 139
# Moving image 140
# Moving image 141
# Moving image 142
# Moving image 143
# Moving image 144
# Moving image 145
# Moving image 146
# Moving image 147
# Moving image 148
# Moving image 149
# Moving image 150
# Moving image 151
# Moving image 152
# Moving image 153
# Moving image 154
# Moving image 155
# Moving image 156
# Moving image 157
# Moving image 158
# Moving image 159
# Moving image 160
# Moving image 161
# Moving image 162
# Moving image 163
# Moving image 164
# Moving image 165
# Moving image 166
# Moving image 167
# Moving image 168
# Moving image 169
# Moving image 170
# Moving image 171
# Moving image 172
# Moving image 173
# Moving image 174
# Moving image 175
# Moving image 176
# Moving image 177
# Moving image 178
# Moving image 179
# Moving image 180
# Moving image 181
# 182
